# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GROQ_API_KEY")

print("API key loaded:", bool(api_key))

# %%
from groq import Groq

client = Groq(api_key=api_key)

models = client.models.list()

for model in models.data:
    print(model.id)
# Out:
# openai/gpt-oss-20b
# groq/compound-mini
# allam-2-7b
# meta-llama/llama-prompt-guard-2-86m
# meta-llama/llama-prompt-guard-2-22m
# qwen/qwen3.8-27b
# groq/compound
# canopylabs/orpheus-arabic-saudi
# openai/gpt-oss-safeguard-20b
# canopylabs/orpheus-v1-english
# whisper-large-v3
# openai/gpt-oss-120b
# whisper-large-v3-turbo

# %%
MODEL_NAME = "qwen/qwen3.8-27b"

response = client.chat.completions.create(
    model=MODEL_NAME,
    messages=[
        {
            "role": "user",
            "content": "Explain an email triage agent in two sentences."
        }
    ],
    temperature=0,
)

print(response.choices[0].message.content)
# Out:
# An email triage agent is an automated system that uses artificial intelligence to analyze incoming messages, categorizing them by priority, sender, or topic to streamline workflow. It ensures that critical communications are flagged for immediate attention while routine items are sorted or archived, allowing users to focus on high-value tasks.

# %%
from langchain_groq import ChatGroq
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("GROQ_API_KEY")

MODEL_NAME = "qwen/qwen3.8-27b"

llm = ChatGroq(
    model=MODEL_NAME,
    api_key=api_key,
    temperature=0,
)

# %%
response = llm.invoke(
    "Explain what an AI email triage agent does in two sentences."
)

print(response.content)
# Out:
# An AI email triage agent automatically analyzes incoming messages to categorize them by priority, sender, and content relevance. It then routes these emails to appropriate folders, flags urgent items, or drafts responses to streamline workflow and reduce manual sorting efforts.
